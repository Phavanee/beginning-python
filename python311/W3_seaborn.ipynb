# %% [markdown]
# # Seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
# Load an example dataset
#tips = sns.load_dataset("tips")
tips = pd.read_csv('tips.csv')

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)
# Out:
# /home/span/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(data=tips, x="total_bill", y="tip", col="time", hue="smoker")
# Out:
# /home/span/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=tips, x="total_bill", col="time", kde=True)
# Out:
# /home/span/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#dots = sns.load_dataset("dots")
dots = pd.read_csv('dots.csv')
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)
# Out:
# /home/span/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
fmri = sns.load_dataset("fmri")
sns.relplot(
    data=fmri, kind="line",
    x="timepoint", y="signal", col="region",
    hue="event", style="event",
)
# Out:
# /home/span/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
diamonds = pd.read_csv("dataset/Diamonds Prices2022.csv")

diamonds.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
sns.lmplot(data=diamonds, x="carat", y="price", col='color')
# Out:
# /home/span/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lineplot(
    x="clarity",
    y="price",
    data=diamonds,
    estimator=sum,
    ci=None,
    ls='--',
    color='green'
)
# Out:
# /tmp/ipykernel_15660/3149562490.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(
# <Axes: xlabel='clarity', ylabel='price'>

# %% [markdown]
# ## Seaborn Barplots

# %%
sns.barplot(
    x="cut",
    y="carat",
    data=diamonds,
)
# Out:
# <Axes: xlabel='cut', ylabel='carat'>

# %%
# Specify the numeric series as x to create a horizontal bar chart

sns.barplot(
    x="carat",
    y="cut",
    data=diamonds,
    ci=None
)
# Out:
# /tmp/ipykernel_15660/3754973106.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# <Axes: xlabel='carat', ylabel='cut'>

# %%
# Matplotlib formatting options generally apply to seaborn counterparts

sns.barplot(
    x="carat",
    y="cut",
    data=diamonds,
    facecolor="white",
    edgecolor="black"
)
# Out:
# <Axes: xlabel='carat', ylabel='cut'>

# %%
# Specify a categorical column in 'hue' to created grouped barplots

sns.barplot(
    x="carat",
    y="cut",
    hue="color",
    data=diamonds.sort_values(by="color"),
    palette='viridis'
)
# Out:
# <Axes: xlabel='carat', ylabel='cut'>

# %% [markdown]
# ## Histograms

# %%
sns.histplot(
    x="price", 
    bins=10, 
    kde=True, 
    stat='percent',
    data=diamonds
)
# Out:
# <Axes: xlabel='price', ylabel='Percent'>

# %% [markdown]
# ## Box and Violinplots

# %%
sns.boxplot(x="price", data=diamonds)
# Out:
# <Axes: xlabel='price'>

# %%
sns.boxplot(x="cut", y="price", data=diamonds)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
sns.violinplot(x="price", data=diamonds)
# Out:
# <Axes: xlabel='price'>

# %%
sns.violinplot(x="cut", y="price", data=diamonds)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %% [markdown]
# # LMPLOT & REGPLOT

# %%
sns.scatterplot(
    x="carat", 
    y="price",
    alpha=.3,
    data=diamonds.sample(1000)
)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.regplot(
    x="carat", 
    y="price",
    scatter_kws={'alpha': .3},
    data=diamonds.sample(1000)
)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
sns.lmplot(
    x="carat", 
    y="price", 
    # hue="clarity",
    line_kws={'alpha': .3},
    # fit_reg=False,
    data=diamonds
)
# Out:
# /home/span/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(
    x="carat", 
    y="price", 
    # row="cut",
    col="clarity",
    fit_reg=False,
    # scatter=False,
    hue="cut",
    # by="cut",
    # alpha=.3
    data=diamonds
)
# Out:
# /home/span/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Jointplot

# %%
sns.jointplot(
    x="carat", 
    y="price", 
    kind='kde',
    data=diamonds
)

# %%
sns.jointplot(x="carat", y="price", hue="clarity", data=diamonds)

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(diamonds.loc[:, ["carat", "x", "y", "z"]])
# Out:
# /home/span/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Heatmaps

# %%
diamonds_pivot = (
    diamonds.pivot_table(
        index="clarity",
        columns="color",
        values={"price":"mean"}
        )
).droplevel(0, axis=1)

diamonds_pivot.head()
# Out:
# color              D            E            F            G            H  \
# clarity
# I1       3863.023810  3488.421569  3342.181818  3545.693333  4453.413580
# IF       8307.369863  3668.506329  2750.836364  2558.033774  2287.869565
# SI1      2976.146423  3161.670787  3713.776266  3774.787449  5032.414945
# SI2      3931.101460  4173.826036  4472.625233  5021.684109  6099.895074
# VS1      3030.158865  2856.294301  3796.717742  4131.362197  3780.688623
#
# color              I            J
# clarity
# I1       4302.184783  5254.060000
# IF       1994.937063  3363.882353
# SI1      5355.019663  5186.048000
# SI2      7002.649123  6520.958246
# VS1      4633.183992  4884.461255

# %%
sns.heatmap(diamonds_pivot)
# Out:
# <Axes: xlabel='color', ylabel='clarity'>

# %%
sns.heatmap(
    diamonds_pivot.iloc[5:, 4:],
    annot=True,
    fmt='g',
    cmap="RdYlGn"
)
# Out:
# <Axes: xlabel='color', ylabel='clarity'>

# %%
diamonds.drop('color', axis=1)
# Out:
#        Unnamed: 0  carat        cut clarity  depth  table  price     x     y  \
# 0               1   0.23      Ideal     SI2   61.5   55.0    326  3.95  3.98
# 1               2   0.21    Premium     SI1   59.8   61.0    326  3.89  3.84
# 2               3   0.23       Good     VS1   56.9   65.0    327  4.05  4.07
# 3               4   0.29    Premium     VS2   62.4   58.0    334  4.20  4.23
# 4               5   0.31       Good     SI2   63.3   58.0    335  4.34  4.35
# ...           ...    ...        ...     ...    ...    ...    ...   ...   ...
# 53938       53939   0.86    Premium     SI2   61.0   58.0   2757  6.15  6.12
# 53939       53940   0.75      Ideal     SI2   62.2   55.0   2757  5.83  5.87
# 53940       53941   0.71    Premium     SI1   60.5   55.0   2756  5.79  5.74
# 53941       53942   0.71    Premium     SI1   59.8   62.0   2756  5.74  5.73
# 53942       53943   0.70  Very Good     VS2   60.5   59.0   2757  5.71  5.76
#
#           z
# 0      2.43
# 1      2.31
# 2      2.31
# 3      2.63
# 4      2.75
# ...     ...
# 53938  3.74
# 53939  3.64
# 53940  3.49
# 53941  3.43
# 53942  3.47
#
# [53943 rows x 10 columns]

# %%
import numpy as np

sns.set_style("white")

diamonds = diamonds.drop('cut', axis=1)
diamonds = diamonds.drop('color', axis=1)
diamonds = diamonds.drop('clarity', axis=1)
diamonds_corr = diamonds.corr()

diamonds_corr

# Getting the Upper Triangle of the correlation matrix

matrix = np.triu(diamonds_corr)

sns.heatmap(
    diamonds_corr, 
    cmap="vlag", 
    annot=True,
    mask=matrix      
)
# Out:
# <Axes: >

# %% [markdown]
# ## FacetGrid

# %%
import matplotlib.pyplot as plt

def annotate(data, **kws):
    n = len(data)
    ax = plt.gca()
    ax.text(.7, .1, f"N = {n}", transform=ax.transAxes)

g = sns.FacetGrid(diamonds, col="color", col_wrap=3)
g.map_dataframe(sns.scatterplot, x="carat", y="price")
g.map_dataframe(annotate)
# Out:
# /home/span/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.FacetGrid(diamonds, col="color", col_wrap=3)

g.map_dataframe(sns.histplot, x="price")
# Out:
# /home/span/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Matplotlib Integration

# %%
fig, ax = plt.subplots(2, 2)

sns.regplot(ax=ax[0][0], x="carat", y="price", data=diamonds)

sns.heatmap((diamonds
             .pivot_table(index="cut",
                      columns="clarity",
                      values={"price":"mean"}
                     )
             .droplevel(0, axis=1)
        ),
            ax = ax[0][1]
)

ax[1][0].hist(diamonds["price"])

ax[1][1].bar(x=diamonds["color"], height=diamonds["price"])

fig.tight_layout()

plt.show()

# %%
fig, ax = plt.subplots(figsize=(6.4, 4))

sns.set_style("darkgrid")

sns.barplot(x="cut",
            y="carat",
            data=diamonds)

ax.set_title("Average Carat Weight by Cut Quality", fontsize=16)
ax.set_xlabel("Cut Quality")
ax.set_ylabel("Carat Weight")
# Out:
# Text(0, 0.5, 'Carat Weight')

# %%
fig, ax = plt.subplots(2, 1, figsize=(8, 6))

sns.set_style("darkgrid")

sns.barplot(
    x="cut",
    y="carat",
    data=diamonds,
    ax=ax[0]
)

ax[0].set_title("Carat Weight by Cut Quality", fontsize=16)
ax[0].set_ylabel("Carat Weight")
ax[0].set_xlabel("Cut Quality")

ax[1].hist(diamonds["carat"], density=True)
ax[1].set_title("Distribution of Carat Weight", fontsize=16)
ax[1].set_xlabel("Carat Weight")
ax[1].set_ylabel("Percent of Diamonds")

fig.tight_layout()
